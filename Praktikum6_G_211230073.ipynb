# %% [markdown]
# <a href="https://colab.research.google.com/github/nenggoloo9405/Komputer-Grafis/blob/main/Praktikum6_G_211230073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dfc0f41a-f585-41c2-81b7-d1b759e5addc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfc0f41a-f585-41c2-81b7-d1b759e5addc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# resizing 0.5

img = cv2.imread('bondolan.jpg')
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img3 = cv2.resize(img2,None,fx=0.5, fy=0.5, interpolation = cv2.INTER_CUBIC)
plt.imshow(img3)

# %%
# resizing 2

height, width = img.shape[:2]
res = cv2.resize(img2,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
plt.imshow(res)

# %%
#translation
rows,cols = img2.shape[:2]
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img2,M,(cols,rows))
plt.imshow(dst)

# %%
# rotation 90
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(img2,M,(cols,rows))
plt.imshow(dst)

# %%
#Affine transfomation

rows,cols,ch = img2.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img2,M,(cols,rows))
plt.imshow(dst)

# %%
# prespective transform

pts1 = np.float32([[56,56],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img2,M,(300,300))
plt.imshow(dst)
